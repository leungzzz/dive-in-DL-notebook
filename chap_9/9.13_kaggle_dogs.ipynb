# %% [markdown]
# ### 说明：
#
# kaggle_dog狗品种分类比赛是一个经典分类模板。它提供的数据集数据结构如下：提供train(里面包含了所有待分类的狗)、test(里面提供了测试集)，label.csv文件，用于指示train文件夹、test文件夹里面的每张照片所对应的是哪一个品种的狗。
#
# 要做什么？
#
# 1. 先将train数据集分类好。通过遍历train文件夹中的每张图片、csv文件的辅助，将每一个品种的小狗的数据归类到该品种的小狗的文件夹下。
#
# 2.

# %%
import collections
import math

import os
import shutil
import time
import zipfile

import sys
sys.path.append('../d2lzh/')
import d2lzh_pytorch as d2l

import torch
import torchvision

# %% [markdown]
# 设置demo是为了用部分数据去训练模型（原数据太多），使用500张图片进行测试，50张图片进行验证。

# %%
demo = False
data_dir = '/home/tpg/Datasets/kaggle_dog/'

# %%
### 整理数据集

def reorg_train_valid(data_dir, train_dir, input_dir, valid_ratio, idx_label):
    """
    Function:
        将每一类狗狗的照片归类这类狗狗的文件夹下。
    Args:
        valid_ratio: 验证集中，每类狗的样本数与原始数据集中包含狗的样本数最少的那一类的样本数之比。
        idx_label: 字典结构。
    Return:
        None
    """

    # 找出包含狗的样本数最少的那一类
    min_n_train_per_label = (collections.Counter(
        idx_label.values()).most_common()[:-2:-1][0][1])

    # 验证集中每类狗的样本数
    n_valid_per_label = math.floor(min_n_train_per_label * valid_ratio)
    label_count = {}
    for train_file in os.listdir(os.path.join(data_dir, train_dir)):
        idx = train_file.split('.')[0]
        label = idx_label[idx]
        d2l.mkdir_if_not_exist([data_dir, input_dir, 'train_valid', label])
        shutil.copy(os.path.join(data_dir, train_dir, train_file),
                    os.path.join(data_dir, input_dir, 'train_valid', label))
        if label not in label_count or label_count[label] < n_valid_per_label:
            d2l.mkdir_if_not_exist([data_dir, input_dir, 'valid', label])
            shutil.copy(os.path.join(data_dir, train_dir, train_file),
                        os.path.join(data_dir, input_dir, 'valid', label))
            label_count[label] = label_count.get(label, 0) + 1

        else:
            d2l.mkdir_if_not_exist([data_dir, input_dir, 'train', label])
            shutil.copy(os.path.join(data_dir, train_dir, train_file),
                        os.path.join(data_dir, input_dir, 'train', label))


def reorg_dog_data(data_dir, label_dir, train_dir, test_dir, input_dir,
                   valid_ratio):

    with open(os.path.join(data_dir, label_dir), 'r') as f:
        lines = f.readlines()[1:]
        tokens = [l.rstrip().split(',') for l in lines]
        idx_label = dict(((idx, label) for idx, label in tokens))

    reorg_train_valid(data_dir, train_dir, input_dir, valid_ratio, idx_label)

    d2l.mkdir_if_not_exist([data_dir, input_dir, 'test', 'unknown'])

    for test_file in os.listdir(os.path.join(data_dir, test_dir)):
        shutil.copy(os.path.join(data_dir, test_dir, test_file),
                    os.path.join(data_dir, input_dir, 'test', 'unknown'))

# %%
### 通过调用函数，完成小狗数据的归类

if demo:
    input_dir, batch_size = 'train_valid_test_tiny', 1
else:
    label_file, train_dir, test_dir = 'labels.csv', 'train', 'test'
    input_dir, batch_size, valid_ratio = 'train_valid_test', 16, 0.1
    reorg_dog_data(data_dir, label_file, train_dir, test_dir, input_dir, valid_ratio)

# %%
### 图像增广

transform_train = torchvision.transforms.Compose([
        torchvision.transforms.RandomResizedCrop(224, 
                                                 scale=(0.08, 1.0),
                                                ratio=(3.0/4.0, 4.0/3.0)),
        torchvision.transforms.RandomHorizontalFlip(),
        torchvision.transforms.ColorJitter(brightness=0.4, 
                                          contrast=0.4,
                                          saturation=0.4),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize(
            [0.485, 0.456, 0.406],
            [0.229, 0.224, 0.225],
        ),
        
    ])

transform_test = torchvision.transforms.Compose([
        torchvision.transforms.Resize(256),
        torchvision.transforms.CenterCrop(224),
        torchvision.transforms.ToTensor(),
        torchvision.transforms.Normalize(
            [0.485, 0.456, 0.406],
            [0.229, 0.224, 0.225],
        ),
    ])

# %%
### 读取数据集，并完成封装iter.

from torchvision.datasets import ImageFolder as IF
from torch.utils.data import DataLoader as DL

train_data_path = os.path.join(data_dir, input_dir, 'train')
train_data = IF(train_data_path, transform=transform_train)

valid_data_path = os.path.join(data_dir, input_dir, 'valid')
valid_data = IF(valid_data_path, transform=transform_train)

train_valid_data_path = os.path.join(data_dir, input_dir, 'train_valid')
train_valid_data = IF(train_valid_data_path, transform=transform_train)

test_data_path = os.path.join(data_dir, input_dir, test_dir)
test_data = IF(test_data_path, transform=transform_test)

# 封装
train_iter = DL(train_data, batch_size, shuffle=True)
valid_iter = DL(valid_data, batch_size, shuffle=True)
train_valid_iter = DL(train_valid_data, batch_size, shuffle=True)
test_iter = DL(test_data, batch_size, shuffle=False)

# %%
### 定义模型
# 由于dog数据集是ImageNet的子集，所有采用fine tuning的思想来进行迁移学习

from torchvision import models
from torch import nn, optim

pretrained_net = models.resnet34(pretrained=True) # 下载模型(如果为True)

# print(pretrained_net)
# print(pretrained_net.fc)
pretrained_net.fc = nn.Linear(512, 120)  # 参数已经完成初始化，但其他层的参数依旧保持不变
# print(pretrained_net.fc)

# %%
### 更改模型的学习率（前面参数的学习率较低、最后一层参数的学习率较高）

# 先列出参数
output_params = list(map(id, pretrained_net.fc.parameters()))
# print(output_params)

# 过滤出其他参数
feature_params = filter(lambda p: id(p) not in output_params, pretrained_net.parameters())
# print(feature_params)

lr = 0.01
optimizer = optim.SGD([
        {'params': feature_params},
        {'params': pretrained_net.fc.parameters(), 'lr':lr * 10}],
        lr=lr, weight_decay=0.001,
    )

# %%
### 定义训练函数

def train(net, train_iter, valid_iter, loss, optimizer, num_epochs, device):
    
    net = net.to(device)
    print("training on:", device)
    batch_count = 0
    
    for epoch in range(num_epochs):
        train_l_sum, train_acc_sum, bs = 0.0, 0.0, 0        
        start = time.time()
        
        for X, y in train_iter:
            X = X.to(device)
            y = y.to(device)
            y_hat = net(X)
            l = loss(y_hat, y)
            optimizer.zero_grad()
            l.backward()
            optimizer.step()
            
            train_l_sum += l.cpu().item()
            train_acc_sum += (y_hat.argmax(dim=1) == y).sum().cpu().item()
            bs += y.shape[0]
            batch_count += 1
            
        if valid_iter is not None:
            valid_acc = d2l.evaluate_accuracy(valid_iter, net)
            acc_str = ("train acc %.4f, valid acc %.4f," 
                        % (train_acc_sum / bs, valid_acc))
        else:
            acc_str = ("train acc %.4f," % (train_acc_sum / bs))
            
        print("epoch %d, train loss %.3f," % (epoch + 1, train_l_sum / batch_count) 
              + acc_str + "time %.2f" % (time.time() - start))

# %%
### 开始训练(暂时先不测试)

loss = torch.nn.CrossEntropyLoss()
device = 'cuda' if torch.cuda.is_available() else 'cpu'
num_epochs = 200

train(pretrained_net, train_iter, valid_iter, loss, optimizer, num_epochs, device)

保存
PATH = "./pretrained_resnet34_my.pth"
torch.save(pretrained_net.state_dict(), PATH)

#　加载
# model = models.resnet34(pretrained=False) 
# model.fc = nn.Linear(512, 120)
# model.load_state_dict(torch.load(PATH))
# model.state_dict()
# Out:
# training on: cuda
# epoch 1, train loss 2.591,train acc 0.3917, valid acc 0.4125,time 97.66
# epoch 2, train loss 0.921,train acc 0.5200, valid acc 0.5361,time 99.12
# epoch 3, train loss 0.550,train acc 0.5551, valid acc 0.5014,time 100.47
# epoch 4, train loss 0.385,train acc 0.5862, valid acc 0.5986,time 103.32
# epoch 5, train loss 0.291,train acc 0.6086, valid acc 0.5583,time 102.95
# epoch 6, train loss 0.225,train acc 0.6306, valid acc 0.5639,time 103.78
# epoch 7, train loss 0.190,train acc 0.6373, valid acc 0.5903,time 102.73
# epoch 8, train loss 0.157,train acc 0.6505, valid acc 0.5819,time 103.80
# epoch 9, train loss 0.134,train acc 0.6708, valid acc 0.5528,time 101.91
# epoch 10, train loss 0.116,train acc 0.6748, valid acc 0.5931,time 101.83
# epoch 11, train loss 0.102,train acc 0.6946, valid acc 0.5653,time 101.54
# epoch 12, train loss 0.090,train acc 0.7017, valid acc 0.6000,time 102.01
# epoch 13, train loss 0.083,train acc 0.7025, valid acc 0.6083,time 103.26
# epoch 14, train loss 0.075,train acc 0.7073, valid acc 0.5903,time 103.46
# epoch 15, train loss 0.068,train acc 0.7145, valid acc 0.6097,time 102.46
# epoch 16, train loss 0.062,train acc 0.7275, valid acc 0.5333,time 101.93
# epoch 17, train loss 0.055,train acc 0.7398, valid acc 0.5417,time 101.83
# epoch 18, train loss 0.052,train acc 0.7424, valid acc 0.5972,time 103.04
# epoch 19, train loss 0.048,train acc 0.7445, valid acc 0.5931,time 100.80
# epoch 20, train loss 0.043,train acc 0.7630, valid acc 0.5958,time 101.44
# epoch 21, train loss 0.042,train acc 0.7603, valid acc 0.6000,time 100.85
# epoch 22, train loss 0.040,train acc 0.7578, valid acc 0.5889,time 101.03
# epoch 23, train loss 0.036,train acc 0.7762, valid acc 0.6194,time 101.49
# epoch 24, train loss 0.034,train acc 0.7737, valid acc 0.5986,time 103.58
# epoch 25, train loss 0.033,train acc 0.7736, valid acc 0.5889,time 103.19
# epoch 26, train loss 0.031,train acc 0.7843, valid acc 0.5792,time 102.19
# epoch 27, train loss 0.030,train acc 0.7804, valid acc 0.5903,time 102.29
# epoch 28, train loss 0.028,train acc 0.7885, valid acc 0.5861,time 103.35
# epoch 29, train loss 0.026,train acc 0.7897, valid acc 0.5708,time 103.48
# epoch 30, train loss 0.026,train acc 0.7899, valid acc 0.6097,time 102.15
# epoch 31, train loss 0.025,train acc 0.7954, valid acc 0.6083,time 101.29
# epoch 32, train loss 0.024,train acc 0.7981, valid acc 0.5819,time 101.28
# epoch 33, train loss 0.023,train acc 0.7992, valid acc 0.5917,time 101.29
# epoch 34, train loss 0.022,train acc 0.8006, valid acc 0.5944,time 101.42
# epoch 35, train loss 0.021,train acc 0.8089, valid acc 0.6153,time 100.98
# epoch 36, train loss 0.020,train acc 0.8064, valid acc 0.5708,time 100.77
# epoch 37, train loss 0.019,train acc 0.8136, valid acc 0.5931,time 100.96
# epoch 112, train loss 0.005,train acc 0.8488, valid acc 0.5694,time 100.65
# epoch 113, train loss 0.005,train acc 0.8475, valid acc 0.5639,time 100.44
# epoch 114, train loss 0.005,train acc 0.8593, valid acc 0.6028,time 101.98
# epoch 115, train loss 0.005,train acc 0.8587, valid acc 0.5653,time 101.36
# epoch 116, train loss 0.005,train acc 0.8437, valid acc 0.5486,time 100.74
# epoch 117, train loss 0.005,train acc 0.8572, valid acc 0.5833,time 100.44
# epoch 118, train loss 0.005,train acc 0.8521, valid acc 0.5750,time 101.31
# epoch 119, train loss 0.005,train acc 0.8493, valid acc 0.5639,time 100.16
# epoch 120, train loss 0.005,train acc 0.8481, valid acc 0.5597,time 100.30
# epoch 121, train loss 0.005,train acc 0.8511, valid acc 0.5472,time 100.20
# epoch 122, train loss 0.005,train acc 0.8534, valid acc 0.5361,time 100.25
# epoch 123, train loss 0.005,train acc 0.8549, valid acc 0.5472,time 100.19
# epoch 124, train loss 0.005,train acc 0.8535, valid acc 0.5639,time 100.86
# epoch 125, train loss 0.005,train acc 0.8522, valid acc 0.5764,time 100.44
# epoch 126, train loss 0.005,train acc 0.8485, valid acc 0.5681,time 101.05
# epoch 127, train loss 0.005,train acc 0.8528, valid acc 0.5528,time 100.24
# epoch 128, train loss 0.004,train acc 0.8648, valid acc 0.5375,time 103.84
# epoch 129, train loss 0.005,train acc 0.8514, valid acc 0.5667,time 101.48
# epoch 130, train loss 0.005,train acc 0.8527, valid acc 0.5806,time 101.91
# epoch 131, train loss 0.004,train acc 0.8575, valid acc 0.5806,time 101.96
# epoch 132, train loss 0.004,train acc 0.8521, valid acc 0.5361,time 101.02
# epoch 133, train loss 0.005,train acc 0.8449, valid acc 0.5722,time 101.68
# epoch 134, train loss 0.004,train acc 0.8561, valid acc 0.5556,time 100.23
# epoch 135, train loss 0.004,train acc 0.8523, valid acc 0.5486,time 100.66
# epoch 136, train loss 0.004,train acc 0.8560, valid acc 0.5792,time 101.18
# epoch 137, train loss 0.004,train acc 0.8551, valid acc 0.5417,time 102.69
# epoch 138, train loss 0.004,train acc 0.8510, valid acc 0.5903,time 101.64
# epoch 139, train loss 0.004,train acc 0.8575, valid acc 0.5250,time 102.70
# epoch 140, train loss 0.004,train acc 0.8513, valid acc 0.5542,time 102.21
# epoch 141, train loss 0.004,train acc 0.8659, valid acc 0.5681,time 101.48
# epoch 142, train loss 0.004,train acc 0.8601, valid acc 0.5403,time 99.93
# epoch 143, train loss 0.004,train acc 0.8562, valid acc 0.5472,time 102.98
# epoch 144, train loss 0.004,train acc 0.8532, valid acc 0.5403,time 99.95
# epoch 145, train loss 0.004,train acc 0.8569, valid acc 0.5778,time 101.07
# epoch 146, train loss 0.004,train acc 0.8463, valid acc 0.5472,time 102.48
# epoch 147, train loss 0.004,train acc 0.8576, valid acc 0.5472,time 101.32
# epoch 148, train loss 0.004,train acc 0.8536, valid acc 0.5639,time 100.30
# epoch 149, train loss 0.004,train acc 0.8510, valid acc 0.5458,time 101.17
# epoch 150, train loss 0.004,train acc 0.8548, valid acc 0.5444,time 100.63
# epoch 151, train loss 0.004,train acc 0.8569, valid acc 0.5583,time 100.20
# epoch 152, train loss 0.004,train acc 0.8565, valid acc 0.5569,time 100.11
# epoch 153, train loss 0.004,train acc 0.8498, valid acc 0.5417,time 101.75
# epoch 154, train loss 0.004,train acc 0.8490, valid acc 0.5361,time 102.08
# epoch 155, train loss 0.004,train acc 0.8553, valid acc 0.5472,time 100.42
# epoch 156, train loss 0.004,train acc 0.8545, valid acc 0.5431,time 101.63
# epoch 157, train loss 0.004,train acc 0.8529, valid acc 0.5542,time 99.88
# epoch 158, train loss 0.004,train acc 0.8533, valid acc 0.5639,time 100.57
# epoch 159, train loss 0.004,train acc 0.8585, valid acc 0.5583,time 102.57
# epoch 160, train loss 0.004,train acc 0.8517, valid acc 0.5667,time 102.20
# epoch 161, train loss 0.004,train acc 0.8489, valid acc 0.5708,time 100.80
# epoch 162, train loss 0.004,train acc 0.8509, valid acc 0.5764,time 100.49
# epoch 163, train loss 0.004,train acc 0.8531, valid acc 0.5750,time 101.07
# epoch 164, train loss 0.003,train acc 0.8617, valid acc 0.5444,time 100.01
# epoch 165, train loss 0.004,train acc 0.8561, valid acc 0.5139,time 99.65
# epoch 166, train loss 0.004,train acc 0.8520, valid acc 0.5444,time 99.86
# epoch 167, train loss 0.003,train acc 0.8609, valid acc 0.5417,time 101.25
# epoch 168, train loss 0.003,train acc 0.8609, valid acc 0.5597,time 99.75
# epoch 169, train loss 0.004,train acc 0.8517, valid acc 0.5917,time 100.52
# epoch 170, train loss 0.004,train acc 0.8510, valid acc 0.5514,time 99.66
# epoch 171, train loss 0.004,train acc 0.8489, valid acc 0.5403,time 101.06
# epoch 172, train loss 0.003,train acc 0.8569, valid acc 0.5486,time 101.71
# epoch 173, train loss 0.003,train acc 0.8628, valid acc 0.5444,time 99.65
# epoch 174, train loss 0.003,train acc 0.8528, valid acc 0.5486,time 99.99
# epoch 175, train loss 0.003,train acc 0.8553, valid acc 0.5597,time 100.67
# epoch 176, train loss 0.003,train acc 0.8577, valid acc 0.5431,time 101.52
# epoch 177, train loss 0.003,train acc 0.8603, valid acc 0.5458,time 101.39
# epoch 178, train loss 0.003,train acc 0.8583, valid acc 0.5069,time 101.15
# epoch 179, train loss 0.003,train acc 0.8591, valid acc 0.5250,time 101.19
# epoch 180, train loss 0.003,train acc 0.8536, valid acc 0.5486,time 100.19
# epoch 181, train loss 0.003,train acc 0.8434, valid acc 0.5472,time 99.76
# epoch 182, train loss 0.003,train acc 0.8472, valid acc 0.5389,time 100.79
# epoch 183, train loss 0.003,train acc 0.8590, valid acc 0.5556,time 100.79
# epoch 184, train loss 0.003,train acc 0.8558, valid acc 0.5403,time 100.65
# epoch 185, train loss 0.003,train acc 0.8593, valid acc 0.5472,time 99.78
# epoch 186, train loss 0.003,train acc 0.8600, valid acc 0.5319,time 100.45
# epoch 187, train loss 0.003,train acc 0.8597, valid acc 0.5375,time 99.58
# epoch 188, train loss 0.003,train acc 0.8513, valid acc 0.5444,time 101.29
# epoch 189, train loss 0.003,train acc 0.8586, valid acc 0.5333,time 100.21
# epoch 190, train loss 0.003,train acc 0.8413, valid acc 0.5486,time 100.05
# epoch 191, train loss 0.003,train acc 0.8540, valid acc 0.5500,time 102.45
# epoch 192, train loss 0.003,train acc 0.8570, valid acc 0.5361,time 101.60
# epoch 193, train loss 0.003,train acc 0.8505, valid acc 0.5319,time 99.58
# epoch 194, train loss 0.003,train acc 0.8555, valid acc 0.5319,time 99.02
# epoch 195, train loss 0.003,train acc 0.8542, valid acc 0.5375,time 100.16
# epoch 196, train loss 0.003,train acc 0.8500, valid acc 0.4958,time 99.98
# epoch 197, train loss 0.003,train acc 0.8551, valid acc 0.5486,time 101.23
# epoch 198, train loss 0.003,train acc 0.8567, valid acc 0.5181,time 100.21
# epoch 199, train loss 0.003,train acc 0.8566, valid acc 0.5389,time 99.50
# epoch 200, train loss 0.003,train acc 0.8571, valid acc 0.5486,time 99.98
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-edc2d82ad21f> in <module>()
#       7 train(pretrained_net, train_iter, valid_iter, loss, optimizer, num_epochs, device)
#       8
# ----> 9 保存
#      10 PATH = "./pretrained_resnet34_my.pth"
#      11 torch.save(pretrained_net.state_dict(), PATH)
#
# NameError: name '保存' is not defined

# %%
# 进入测试环节（用所有训练集训练，所有的测试集进行测试）

# import pandas as pd


# #　加载
# model = models.resnet34(pretrained=False) 
# model.fc = nn.Linear(512, 120)
# model.load_state_dict(torch.load(PATH))
# model.state_dict()

# train(pretrained_net, train_valid_iter, None, loss, optimizer, num_epochs, device)

# # 保存
# PATH = "./pretrained_resnet34_my_old.pth"
# # torch.save(pretrained_net.state_dict(), PATH)

# #　加载
# model = models.resnet34(pretrained=False) 
# model.fc = nn.Linear(512, 120)
# model.load_state_dict(torch.load(PATH))
# # model.state_dict()

# preds = []
# for X, _ in test_iter:
#     y_hat = model(X)
#     preds.extend(y_hat.cpu())   # 将每个样本的预测值计算出来。预测结果如 0,1,2,...,9
    

# print(preds[0])

# ids = sorted(os.listdir(os.path.join(data_dir, input_dir, 'test/unknown')))
# with open("submission.csv", 'w') as f:
#     f.write('id,' + ",".join(train_valid_data.classes) + '\n')
#     for i, output in zip(ids, preds):
#         f.write(i.split('.')[0] + ',' + ','.join([str(num) for num in output]) + '\n')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-7c39cd90b8f2> in <module>()
#      19 model = models.resnet34(pretrained=False)
#      20 model.fc = nn.Linear(512, 120)
# ---> 21 model.load_state_dict(torch.load(PATH))
#      22 # model.state_dict()
#      23
#
# /home/tpg/anaconda3/lib/python3.5/site-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     379             (sys.version_info[0] == 2 and isinstance(f, unicode)):
#     380         new_fd = True
# --> 381         f = open(f, 'rb')
#     382     elif (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     383         new_fd = True
#
# FileNotFoundError: [Errno 2] No such file or directory: './pretrained_resnet34_my.pth'
